# %% [markdown]
# # String

# %%
a=(1,2,2,2,"panna",True,1,5.6 ) 
for i in  a:
    print(i)
# Out:
# 1
# 2
# 2
# 2
# panna
# True
# 1
# 5.6

# %%
print(a)
# Out:
# (1, 2, 2, 2, 'panna', True, 1, 5.6)

# %%
a=(1,2,2,2)   
     
for i in a:
    a.count(i) 
    print(i)
# Out:
# 1
# 2
# 2
# 2
