# %% [markdown]
# ### OOPs is a programming approach where programs are built using classes and objects to represent real-world entities.

# %% [markdown]
# ## Main Features of OOPs
#
# Encapsulation – Data aur functions ko ek unit me bandh kar rakhna
#
# Inheritance – Ek class dusri class ke features use kar sakti hai
#
# Polymorphism – Ek method, multiple forms
#
# Abstraction – Important cheezein dikhana, details hide karna

# %% [markdown]
# ### Explanation of OOPs
#
# OOPs me poora program class aur object par based hota hai:
#
# Class
# Class ek blueprint hoti hai, jisme bataya jata hai object ke pass kaun-kaun se data (variables) aur functions (methods) honge.
#
# Object
# Object class ka real instance hota hai jo memory me jagah leta hai.
#
# Example (real life):
#
# Class = Car
# Objects = BMW, Audi, Swift

# %%
class Temp:

  def __init__(self):      #constructor
    self.pin=''             #variable  
    self.balance=0
    self.menue()
   

  def menue(self):
   user_input=input('1. Check Balance\n2. Deposit\n3. Withdraw\n4. Exit\n')

# %%
obj = Temp()

# %%
class BankAnccount:
 def __init__(self):
  self.pin=''
  self.balance=0
  self.menu()
 def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Press 4 to withdraw
    6. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    elif user_input == '5':
      self.deposit()
    elif user_input == '6':
      self.exit()
    else:
        print('invalid input')
        self.menu() 

 def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

 def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()   
 def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
      self.menu()
    else:
      print('chal nikal yahan se')
      self.menu()
 def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()


 def deposit(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to deposit            
      amount = int(input('enter the amount'))
      self.balance = self.balance + amount
      print('deposit successful.balance is',self.balance)
    else:
      print('sale chor')
    self.menu()
 def exit(self):
   print('thank you for using our service')

# %%
z=BankAnccount()
# Out:
# pin created successfully
# your balance is  50000
# withdrawl successful.balance is 44302
# chal nikal yahan se
# your balance is  44302
# deposit successful.balance is 10000044302
# your balance is  10000044302
# your balance is  10000044302
# thank you for using our service

# %%
x=BankAnccount()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x=BankAnccount()
#
# NameError: name 'BankAnccount' is not defined

# %%
print(z.balance)
print(x.balance)
print(z.pin)
print(x.pin)
# Out:
# 55000
# 797277
# 1234
# 1234

# %%
class Account:
 def __init__(self):
  self.pin=''
  self.balance=0
  self.menu()
 def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Press 4 to withdraw
    6. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    elif user_input == '5':
      self.deposit()
    elif user_input == '6':
      self.exit()
    else:
        print('invalid input')
        self.menu() 

 def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

 def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()   
 def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
      self.menu()
    else:
      print('chal nikal yahan se')
      self.menu()
 def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()


 def deposit(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to deposit            
      amount = int(input('enter the amount'))
      self.balance = self.balance + amount
      print('deposit successful.balance is',self.balance)
    else:
      print('sale chor')
    self.menu()
 def exit(self):
   print('thank you for using our service')

# %%
a=cre
# Out:
# thank you for using our service
# 0
