# %% [markdown]
# # varriable

# %% [markdown]
# * varriable are as container that can store value

# %%
num=int(input("Enter a number: "))
if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# odd
