# %% [markdown]
# # Python introduction

# %% [markdown]
# # what is programming
# programing is a good way write progarm /n
# a=20
# b=30
# result=a+b
# 50

# %%
print('rama',1,True)
# Out:
# rama 1 True

# %%
print('rama',2,False)
# Out:
# rama 2 False
